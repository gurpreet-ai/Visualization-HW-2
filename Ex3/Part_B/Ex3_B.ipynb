# %% [markdown]
# ### Exercise 3 Part B

# %% [markdown]
# Part B: Pandas and Trend Design Problem
#
# Separately for each year (1948-2008) and each city compute the average temperature for that seasons.

# %%
from scipy.io import loadmat
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

def data_format(series):
	time = series['time']
	temp = series['temperature']

	time_temp = zip(time, temp)
	win = ['12', '01', '02']
	spr = ['03', '04', '05']
	sumer = ['06', '07', '08']
	fal   = ['09', '10', '11']

	year = {}
	
	for k, v in enumerate(range(1948, 2009)):
		q = []
		winter = []
		spring = []
		summer = []
		fall = []
		season = {}
		for i, j in time_temp:
			if i[0:4] == str(v):
				if i[5:7] in win:
					j[0] = k2f(j[0])
					winter.append(j[0])
				elif i[5:7] in spr:
					j[0] = k2f(j[0])
					spring.append(j[0])
				elif i[5:7] in sumer:
					j[0] = k2f(j[0])
					summer.append(j[0])
				elif i[5:7] in fal:
					j[0] = k2f(j[0])
					fall.append(j[0])

		season['winter'] = round(np.average(winter), 2)
		season['spring'] = round(np.average(spring), 2)
		season['summer'] = round(np.average(summer), 2)
		season['fall']   = round(np.average(fall), 2)
		
		year[v] = season

	return year

def k2f(t):
    return (t*9/5.0) - 459.67

def read_data(city):
	data = loadmat(city)
	kelvin = data['temperature']
	kelvin = [ j for i in kelvin for j in i]
	x = [k2f(i) for i in kelvin]
	return x, x[0:20000], x[len(x)-20000:]

def set_Spines(x):
	x.spines['top'].set_visible(False)
	x.spines['bottom'].set_linewidth(.8)
	x.xaxis.set_ticks_position('bottom')

	x.spines['right'].set_visible(False)
	x.spines['left'].set_linewidth(0.8)
	x.yaxis.set_ticks_position('left')

def main():
	data = loadmat('Johannesburg.mat')
	series = Series(data)
	Johannesburg = data_format(series)
	print "Johannesburg"
	sorted(Johannesburg.keys())
	for i in Johannesburg:
		print i, " ", Johannesburg[i]

	data = loadmat('Paris.mat')
	series = Series(data)
	Paris = data_format(series)
	print "\nParis"
	sorted(Paris.keys())
	for i in Paris:
		print i, " ", Paris[i]

	data = loadmat('SaoPaulo.mat')
	series = Series(data)
	SaoPaulo = data_format(series)
	print "\nSaoPaulo"
	sorted(SaoPaulo.keys())
	for i in SaoPaulo:
		print i, " ", SaoPaulo[i]

	data = loadmat('Singapore.mat')
	series = Series(data)
	Singapore = data_format(series)
	print "\nSingapore"
	sorted(Singapore.keys())
	for i in Singapore:
		print i, " ", Singapore[i]

	data = loadmat('Sydney.mat')
	series = Series(data)
	Sydney = data_format(series)
	print "\nSydney"
	sorted(Sydney.keys())
	for i in Sydney:
		print i, " ", Sydney[i]

	data = loadmat('Vancouver.mat')
	series = Series(data)
	Vancouver = data_format(series)
	print "\nVancouver"
	sorted(Vancouver.keys())
	for i in Vancouver:
		print i, " ", Vancouver[i]

	"""
	{
		'1948': {
			fall: []
			summer: []
			winter: []
			spring: []
		}
		'1949': {
			fall: []
			summer: []
			winter: []
			spring: []
		}
	}

	# 80,000 = 60 years * 12 months * 4 weeks * 7 days * 4/day
	# 1948 data = 1->60 * 12 * 4 * 7 * 4
	# 1948 monthly = 1->12 * 4 * 7 * 4
	"""

if __name__ == '__main__':
	main()
# Out:
# Johannesburg
# 1948   {'spring': 64.97, 'fall': 72.16, 'winter': 69.08, 'summer': 57.35}
# 1949   {'spring': 64.26, 'fall': 73.7, 'winter': 71.85, 'summer': 59.37}
# 1950   {'spring': 64.84, 'fall': 71.3, 'winter': 69.61, 'summer': 58.7}
# 1951   {'spring': 66.14, 'fall': 74.57, 'winter': 71.59, 'summer': 59.38}
# 1952   {'spring': 65.03, 'fall': 72.41, 'winter': 72.08, 'summer': 58.74}
# 1953   {'spring': 66.07, 'fall': 72.96, 'winter': 72.61, 'summer': 58.28}
# 1954   {'spring': 65.03, 'fall': 72.2, 'winter': 71.64, 'summer': 55.6}
# 1955   {'spring': 63.25, 'fall': 70.5, 'winter': 68.92, 'summer': 57.46}
# 1956   {'spring': 65.18, 'fall': 70.23, 'winter': 68.82, 'summer': 59.31}
# 1957   {'spring': 65.16, 'fall': 72.01, 'winter': 71.5, 'summer': 58.82}
# 1958   {'spring': 65.86, 'fall': 71.04, 'winter': 70.23, 'summer': 58.4}
# 1959   {'spring': 64.04, 'fall': 69.21, 'winter': 68.09, 'summer': 58.69}
# 1960   {'spring': 63.45, 'fall': 72.09, 'winter': 68.17, 'summer': 58.34}
# 1961   {'spring': 66.23, 'fall': 71.14, 'winter': 68.68, 'summer': 58.19}
# 1962   {'spring': 63.54, 'fall': 71.94, 'winter': 68.7, 'summer': 59.81}
# 1963   {'spring': 62.12, 'fall': 72.13, 'winter': 68.24, 'summer': 57.13}
# 1964   {'spring': 63.6, 'fall': 69.58, 'winter': 68.06, 'summer': 55.16}
# 1965   {'spring': 62.67, 'fall': 68.0, 'winter': 69.35, 'summer': 57.76}
# 1966   {'spring': 63.9, 'fall': 68.18, 'winter': 69.63, 'summer': 58.98}
# 1967   {'spring': 63.27, 'fall': 68.88, 'winter': 69.12, 'summer': 55.57}
# 1968   {'spring': 62.39, 'fall': 68.08, 'winter': 69.87, 'summer': 56.66}
# 1969   {'spring': 63.93, 'fall': 68.19, 'winter': 70.99, 'summer': 58.03}
# 1970   {'spring': 64.02, 'fall': 68.66, 'winter': 70.31, 'summer': 58.15}
# 1971   {'spring': 64.25, 'fall': 67.94, 'winter': 68.75, 'summer': 57.14}
# 1972   {'spring': 63.85, 'fall': 67.69, 'winter': 70.92, 'summer': 56.38}
# 1973   {'spring': 64.05, 'fall': 67.28, 'winter': 70.36, 'summer': 56.53}
# 1974   {'spring': 63.02, 'fall': 68.17, 'winter': 70.68, 'summer': 57.12}
# 1975   {'spring': 64.54, 'fall': 68.04, 'winter': 69.04, 'summer': 56.85}
# 1976   {'spring': 63.46, 'fall': 69.13, 'winter': 69.34, 'summer': 56.15}
# 1977   {'spring': 63.55, 'fall': 68.68, 'winter': 70.32, 'summer': 57.07}
# 1978   {'spring': 62.71, 'fall': 67.62, 'winter': 68.32, 'summer': 58.05}
# 1979   {'spring': 65.11, 'fall': 69.45, 'winter': 69.88, 'summer': 56.57}
# 1980   {'spring': 63.41, 'fall': 68.09, 'winter': 69.32, 'summer': 55.24}
# 1981   {'spring': 62.42, 'fall': 65.69, 'winter': 68.49, 'summer': 54.36}
# 1982   {'spring': 63.33, 'fall': 67.21, 'winter': 69.91, 'summer': 57.21}
# 1983   {'spring': 64.77, 'fall': 68.0, 'winter': 69.89, 'summer': 56.32}
# 1984   {'spring': 63.18, 'fall': 68.25, 'winter': 68.9, 'summer': 56.24}
# 1985   {'spring': 63.75, 'fall': 68.85, 'winter': 69.98, 'summer': 57.62}
# 1986   {'spring': 65.52, 'fall': 67.89, 'winter': 68.75, 'summer': 59.34}
# 1987   {'spring': 65.67, 'fall': 67.22, 'winter': 70.41, 'summer': 55.8}
# 1988   {'spring': 64.84, 'fall': 67.41, 'winter': 69.57, 'summer': 57.95}
# 1989   {'spring': 64.04, 'fall': 67.06, 'winter': 68.63, 'summer': 58.55}
# 1990   {'spring': 62.7, 'fall': 68.49, 'winter': 68.79, 'summer': 57.15}
# 1991   {'spring': 63.7, 'fall': 69.5, 'winter': 69.7, 'summer': 56.76}
# 1992   {'spring': 64.94, 'fall': 69.81, 'winter': 70.93, 'summer': 56.18}
# 1993   {'spring': 64.14, 'fall': 68.17, 'winter': 69.08, 'summer': 56.79}
# 1994   {'spring': 63.17, 'fall': 66.89, 'winter': 68.34, 'summer': 54.53}
# 1995   {'spring': 62.94, 'fall': 69.09, 'winter': 68.62, 'summer': 56.54}
# 1996   {'spring': 62.35, 'fall': 68.53, 'winter': 68.02, 'summer': 55.38}
# 1997   {'spring': 62.63, 'fall': 68.49, 'winter': 69.21, 'summer': 58.64}
# 1998   {'spring': 65.63, 'fall': 67.7, 'winter': 69.22, 'summer': 58.35}
# 1999   {'spring': 64.5, 'fall': 66.72, 'winter': 68.39, 'summer': 58.92}
# 2000   {'spring': 62.62, 'fall': 67.4, 'winter': 68.9, 'summer': 57.74}
# 2001   {'spring': 64.51, 'fall': 67.81, 'winter': 68.01, 'summer': 58.72}
# 2002   {'spring': 65.44, 'fall': 67.43, 'winter': 68.81, 'summer': 57.83}
# 2003   {'spring': 65.47, 'fall': 69.64, 'winter': 71.46, 'summer': 56.88}
# 2004   {'spring': 64.95, 'fall': 68.92, 'winter': 70.59, 'summer': 57.73}
# 2005   {'spring': 64.86, 'fall': 71.33, 'winter': 69.83, 'summer': 60.97}
# 2006   {'spring': 62.82, 'fall': 69.43, 'winter': 71.51, 'summer': 57.77}
# 2007   {'spring': 65.99, 'fall': 68.72, 'winter': 70.44, 'summer': 57.61}
# 2008   {'spring': 64.28, 'fall': 70.14, 'winter': 70.19, 'summer': 60.79}
#
# Paris
# 1948   {'spring': 51.76, 'fall': 51.45, 'winter': 39.5, 'summer': 61.66}
# 1949   {'spring': 48.85, 'fall': 52.89, 'winter': 38.48, 'summer': 64.92}
# 1950   {'spring': 49.05, 'fall': 50.91, 'winter': 35.24, 'summer': 65.72}
# 1951   {'spring': 46.4, 'fall': 51.78, 'winter': 39.03, 'summer': 62.59}
# 1952   {'spring': 51.51, 'fall': 46.5, 'winter': 34.04, 'summer': 64.17}
# 1953   {'spring': 51.03, 'fall': 51.12, 'winter': 33.67, 'summer': 62.67}
# 1954   {'spring': 47.71, 'fall': 50.97, 'winter': 34.06, 'summer': 60.19}
# 1955   {'spring': 45.95, 'fall': 48.82, 'winter': 38.11, 'summer': 63.78}
# 1956   {'spring': 48.41, 'fall': 49.32, 'winter': 31.72, 'summer': 59.77}
# 1957   {'spring': 50.16, 'fall': 50.15, 'winter': 37.2, 'summer': 63.37}
# 1958   {'spring': 46.73, 'fall': 50.49, 'winter': 39.05, 'summer': 62.25}
# 1959   {'spring': 51.12, 'fall': 53.14, 'winter': 38.86, 'summer': 65.72}
# 1960   {'spring': 50.42, 'fall': 50.54, 'winter': 35.67, 'summer': 62.32}
# 1961   {'spring': 50.93, 'fall': 53.28, 'winter': 39.8, 'summer': 63.34}
# 1962   {'spring': 44.85, 'fall': 49.95, 'winter': 34.84, 'summer': 63.26}
# 1963   {'spring': 48.09, 'fall': 52.2, 'winter': 26.75, 'summer': 62.32}
# 1964   {'spring': 49.0, 'fall': 49.74, 'winter': 33.81, 'summer': 64.34}
# 1965   {'spring': 47.75, 'fall': 49.93, 'winter': 35.95, 'summer': 60.9}
# 1966   {'spring': 48.31, 'fall': 50.66, 'winter': 39.19, 'summer': 60.9}
# 1967   {'spring': 47.15, 'fall': 51.67, 'winter': 35.2, 'summer': 63.1}
# 1968   {'spring': 47.37, 'fall': 51.45, 'winter': 35.33, 'summer': 61.29}
# 1969   {'spring': 48.19, 'fall': 52.55, 'winter': 33.27, 'summer': 62.22}
# 1970   {'spring': 45.53, 'fall': 52.64, 'winter': 35.28, 'summer': 62.68}
# 1971   {'spring': 47.75, 'fall': 50.1, 'winter': 36.54, 'summer': 62.63}
# 1972   {'spring': 47.72, 'fall': 49.46, 'winter': 38.56, 'summer': 60.71}
# 1973   {'spring': 46.16, 'fall': 50.37, 'winter': 34.39, 'summer': 64.29}
# 1974   {'spring': 48.23, 'fall': 47.37, 'winter': 40.55, 'summer': 62.27}
# 1975   {'spring': 45.91, 'fall': 49.82, 'winter': 37.31, 'summer': 63.74}
# 1976   {'spring': 48.2, 'fall': 50.06, 'winter': 36.38, 'summer': 66.9}
# 1977   {'spring': 47.8, 'fall': 51.18, 'winter': 39.12, 'summer': 60.02}
# 1978   {'spring': 47.16, 'fall': 50.71, 'winter': 37.98, 'summer': 60.31}
# 1979   {'spring': 46.84, 'fall': 51.64, 'winter': 35.56, 'summer': 62.12}
# 1980   {'spring': 46.51, 'fall': 49.94, 'winter': 36.12, 'summer': 60.67}
# 1981   {'spring': 49.69, 'fall': 50.9, 'winter': 35.44, 'summer': 62.13}
# 1982   {'spring': 47.56, 'fall': 52.96, 'winter': 39.29, 'summer': 63.63}
# 1983   {'spring': 46.9, 'fall': 51.41, 'winter': 36.74, 'summer': 66.21}
# 1984   {'spring': 45.57, 'fall': 52.36, 'winter': 36.63, 'summer': 63.22}
# 1985   {'spring': 46.84, 'fall': 50.05, 'winter': 33.87, 'summer': 62.93}
# 1986   {'spring': 46.62, 'fall': 52.34, 'winter': 34.72, 'summer': 63.93}
# 1987   {'spring': 46.93, 'fall': 53.07, 'winter': 32.17, 'summer': 62.75}
# 1988   {'spring': 49.45, 'fall': 51.2, 'winter': 40.56, 'summer': 62.8}
# 1989   {'spring': 51.04, 'fall': 52.21, 'winter': 38.59, 'summer': 65.11}
# 1990   {'spring': 50.59, 'fall': 52.0, 'winter': 39.27, 'summer': 64.93}
# 1991   {'spring': 48.58, 'fall': 51.42, 'winter': 33.97, 'summer': 64.71}
# 1992   {'spring': 50.34, 'fall': 50.56, 'winter': 35.62, 'summer': 64.93}
# 1993   {'spring': 49.78, 'fall': 45.88, 'winter': 38.58, 'summer': 62.94}
# 1994   {'spring': 49.05, 'fall': 52.41, 'winter': 39.44, 'summer': 66.27}
# 1995   {'spring': 48.11, 'fall': 51.75, 'winter': 37.99, 'summer': 66.03}
# 1996   {'spring': 47.27, 'fall': 48.91, 'winter': 35.47, 'summer': 63.49}
# 1997   {'spring': 50.7, 'fall': 52.64, 'winter': 36.94, 'summer': 64.61}
# 1998   {'spring': 49.63, 'fall': 49.07, 'winter': 38.36, 'summer': 63.83}
# 1999   {'spring': 51.49, 'fall': 51.13, 'winter': 38.19, 'summer': 64.39}
# 2000   {'spring': 50.04, 'fall': 52.32, 'winter': 40.14, 'summer': 63.77}
# 2001   {'spring': 50.56, 'fall': 50.53, 'winter': 36.13, 'summer': 64.44}
# 2002   {'spring': 50.7, 'fall': 52.27, 'winter': 41.66, 'summer': 64.11}
# 2003   {'spring': 52.27, 'fall': 51.33, 'winter': 34.77, 'summer': 70.49}
# 2004   {'spring': 48.49, 'fall': 52.34, 'winter': 36.64, 'summer': 64.5}
# 2005   {'spring': 50.22, 'fall': 53.06, 'winter': 34.36, 'summer': 65.16}
# 2006   {'spring': 48.81, 'fall': 56.02, 'winter': 34.47, 'summer': 66.15}
# 2007   {'spring': 52.84, 'fall': 48.98, 'winter': 39.75, 'summer': 61.66}
# 2008   {'spring': 49.2, 'fall': 49.49, 'winter': 37.98, 'summer': 63.26}
#
# SaoPaulo
# 1948   {'spring': 65.47, 'fall': 66.78, 'winter': 67.41, 'summer': 63.06}
# 1949   {'spring': 65.77, 'fall': 66.81, 'winter': 68.45, 'summer': 63.88}
# 1950   {'spring': 67.97, 'fall': 67.06, 'winter': 68.66, 'summer': 65.07}
# 1951   {'spring': 66.04, 'fall': 66.38, 'winter': 69.38, 'summer': 61.59}
# 1952   {'spring': 67.19, 'fall': 67.07, 'winter': 69.88, 'summer': 65.85}
# 1953   {'spring': 68.01, 'fall': 69.79, 'winter': 69.84, 'summer': 63.94}
# 1954   {'spring': 67.91, 'fall': 67.53, 'winter': 70.13, 'summer': 64.81}
# 1955   {'spring': 66.91, 'fall': 64.96, 'winter': 69.14, 'summer': 62.42}
# 1956   {'spring': 64.98, 'fall': 66.97, 'winter': 68.95, 'summer': 60.19}
# 1957   {'spring': 66.16, 'fall': 67.22, 'winter': 69.34, 'summer': 64.54}
# 1958   {'spring': 66.48, 'fall': 68.03, 'winter': 71.06, 'summer': 65.45}
# 1959   {'spring': 68.43, 'fall': 67.81, 'winter': 69.76, 'summer': 64.28}
# 1960   {'spring': 65.31, 'fall': 67.67, 'winter': 68.52, 'summer': 64.0}
# 1961   {'spring': 66.85, 'fall': 70.24, 'winter': 69.46, 'summer': 64.73}
# 1962   {'spring': 66.19, 'fall': 66.1, 'winter': 69.06, 'summer': 62.26}
# 1963   {'spring': 67.14, 'fall': 69.83, 'winter': 69.51, 'summer': 64.37}
# 1964   {'spring': 66.22, 'fall': 66.01, 'winter': 68.72, 'summer': 62.63}
# 1965   {'spring': 66.93, 'fall': 68.54, 'winter': 69.97, 'summer': 64.84}
# 1966   {'spring': 66.79, 'fall': 66.91, 'winter': 70.98, 'summer': 64.85}
# 1967   {'spring': 67.31, 'fall': 69.33, 'winter': 69.18, 'summer': 66.32}
# 1968   {'spring': 65.42, 'fall': 67.24, 'winter': 68.84, 'summer': 61.97}
# 1969   {'spring': 67.54, 'fall': 68.76, 'winter': 70.04, 'summer': 64.95}
# 1970   {'spring': 68.47, 'fall': 66.37, 'winter': 70.71, 'summer': 63.73}
# 1971   {'spring': 67.67, 'fall': 66.0, 'winter': 70.93, 'summer': 64.56}
# 1972   {'spring': 67.54, 'fall': 68.39, 'winter': 70.5, 'summer': 66.3}
# 1973   {'spring': 68.79, 'fall': 66.43, 'winter': 72.05, 'summer': 66.01}
# 1974   {'spring': 67.58, 'fall': 67.0, 'winter': 70.13, 'summer': 64.44}
# 1975   {'spring': 66.52, 'fall': 67.57, 'winter': 70.18, 'summer': 63.89}
# 1976   {'spring': 66.97, 'fall': 66.11, 'winter': 70.1, 'summer': 63.54}
# 1977   {'spring': 67.87, 'fall': 68.09, 'winter': 70.66, 'summer': 66.46}
# 1978   {'spring': 66.57, 'fall': 67.56, 'winter': 70.29, 'summer': 63.26}
# 1979   {'spring': 66.17, 'fall': 67.37, 'winter': 69.01, 'summer': 63.36}
# 1980   {'spring': 69.19, 'fall': 66.7, 'winter': 70.57, 'summer': 65.02}
# 1981   {'spring': 67.35, 'fall': 67.52, 'winter': 70.68, 'summer': 62.61}
# 1982   {'spring': 65.88, 'fall': 68.59, 'winter': 69.48, 'summer': 65.28}
# 1983   {'spring': 68.65, 'fall': 67.05, 'winter': 71.32, 'summer': 65.12}
# 1984   {'spring': 69.11, 'fall': 67.72, 'winter': 71.67, 'summer': 65.34}
# 1985   {'spring': 68.51, 'fall': 67.45, 'winter': 70.13, 'summer': 63.9}
# 1986   {'spring': 68.93, 'fall': 67.28, 'winter': 71.15, 'summer': 64.19}
# 1987   {'spring': 67.4, 'fall': 66.95, 'winter': 70.88, 'summer': 64.66}
# 1988   {'spring': 67.63, 'fall': 66.53, 'winter': 70.62, 'summer': 61.37}
# 1989   {'spring': 66.97, 'fall': 65.57, 'winter': 69.95, 'summer': 62.64}
# 1990   {'spring': 67.87, 'fall': 67.53, 'winter': 70.49, 'summer': 62.18}
# 1991   {'spring': 66.88, 'fall': 66.75, 'winter': 70.13, 'summer': 63.8}
# 1992   {'spring': 67.83, 'fall': 66.0, 'winter': 69.0, 'summer': 63.49}
# 1993   {'spring': 67.26, 'fall': 68.5, 'winter': 69.74, 'summer': 63.89}
# 1994   {'spring': 67.26, 'fall': 68.47, 'winter': 70.52, 'summer': 62.66}
# 1995   {'spring': 66.83, 'fall': 66.63, 'winter': 70.99, 'summer': 65.51}
# 1996   {'spring': 67.04, 'fall': 65.93, 'winter': 71.13, 'summer': 62.04}
# 1997   {'spring': 66.31, 'fall': 69.74, 'winter': 70.59, 'summer': 64.41}
# 1998   {'spring': 68.66, 'fall': 67.24, 'winter': 72.02, 'summer': 64.83}
# 1999   {'spring': 67.25, 'fall': 65.9, 'winter': 71.02, 'summer': 63.3}
# 2000   {'spring': 67.25, 'fall': 68.71, 'winter': 70.76, 'summer': 64.01}
# 2001   {'spring': 69.12, 'fall': 68.04, 'winter': 71.43, 'summer': 65.6}
# 2002   {'spring': 70.03, 'fall': 69.87, 'winter': 70.98, 'summer': 66.73}
# 2003   {'spring': 68.34, 'fall': 67.73, 'winter': 72.06, 'summer': 64.35}
# 2004   {'spring': 67.18, 'fall': 69.04, 'winter': 69.29, 'summer': 62.87}
# 2005   {'spring': 69.14, 'fall': 68.31, 'winter': 69.72, 'summer': 65.18}
# 2006   {'spring': 67.67, 'fall': 67.94, 'winter': 71.76, 'summer': 65.05}
# 2007   {'spring': 69.05, 'fall': 69.19, 'winter': 71.09, 'summer': 64.59}
# 2008   {'spring': 67.95, 'fall': 67.39, 'winter': 69.58, 'summer': 64.57}
#
# Singapore
# 1948   {'spring': 76.5, 'fall': 75.19, 'winter': 75.17, 'summer': 77.43}
# 1949   {'spring': 77.19, 'fall': 75.49, 'winter': 74.63, 'summer': 75.88}
# 1950   {'spring': 78.1, 'fall': 76.45, 'winter': 74.99, 'summer': 77.38}
# 1951   {'spring': 77.43, 'fall': 77.1, 'winter': 74.7, 'summer': 77.17}
# 1952   {'spring': 77.92, 'fall': 77.02, 'winter': 74.75, 'summer': 76.65}
# 1953   {'spring': 77.85, 'fall': 77.01, 'winter': 74.64, 'summer': 77.01}
# 1954   {'spring': 77.17, 'fall': 75.43, 'winter': 75.66, 'summer': 76.86}
# 1955   {'spring': 76.85, 'fall': 75.77, 'winter': 74.6, 'summer': 76.38}
# 1956   {'spring': 76.93, 'fall': 75.68, 'winter': 75.33, 'summer': 76.1}
# 1957   {'spring': 77.21, 'fall': 76.22, 'winter': 75.66, 'summer': 77.34}
# 1958   {'spring': 77.4, 'fall': 76.84, 'winter': 75.61, 'summer': 77.5}
# 1959   {'spring': 77.35, 'fall': 76.67, 'winter': 75.91, 'summer': 76.9}
# 1960   {'spring': 77.17, 'fall': 76.68, 'winter': 75.36, 'summer': 76.95}
# 1961   {'spring': 76.95, 'fall': 75.94, 'winter': 75.37, 'summer': 75.87}
# 1962   {'spring': 76.09, 'fall': 75.77, 'winter': 74.54, 'summer': 75.97}
# 1963   {'spring': 76.47, 'fall': 76.48, 'winter': 74.42, 'summer': 76.2}
# 1964   {'spring': 77.39, 'fall': 76.46, 'winter': 75.82, 'summer': 76.54}
# 1965   {'spring': 77.16, 'fall': 77.18, 'winter': 75.66, 'summer': 76.89}
# 1966   {'spring': 78.07, 'fall': 77.58, 'winter': 76.3, 'summer': 77.32}
# 1967   {'spring': 77.58, 'fall': 76.93, 'winter': 75.76, 'summer': 76.88}
# 1968   {'spring': 77.89, 'fall': 76.88, 'winter': 76.16, 'summer': 77.56}
# 1969   {'spring': 78.41, 'fall': 77.27, 'winter': 76.47, 'summer': 77.31}
# 1970   {'spring': 78.51, 'fall': 77.35, 'winter': 76.61, 'summer': 77.36}
# 1971   {'spring': 77.62, 'fall': 76.38, 'winter': 75.5, 'summer': 76.61}
# 1972   {'spring': 77.53, 'fall': 77.38, 'winter': 76.31, 'summer': 77.76}
# 1973   {'spring': 78.49, 'fall': 77.27, 'winter': 76.47, 'summer': 77.94}
# 1974   {'spring': 77.45, 'fall': 77.07, 'winter': 75.48, 'summer': 77.14}
# 1975   {'spring': 77.62, 'fall': 76.73, 'winter': 75.63, 'summer': 77.15}
# 1976   {'spring': 77.48, 'fall': 77.11, 'winter': 75.7, 'summer': 76.78}
# 1977   {'spring': 78.35, 'fall': 77.45, 'winter': 76.22, 'summer': 77.77}
# 1978   {'spring': 79.0, 'fall': 77.08, 'winter': 76.76, 'summer': 77.8}
# 1979   {'spring': 78.73, 'fall': 77.28, 'winter': 76.51, 'summer': 78.08}
# 1980   {'spring': 78.4, 'fall': 77.1, 'winter': 76.14, 'summer': 77.54}
# 1981   {'spring': 78.6, 'fall': 77.41, 'winter': 75.88, 'summer': 77.72}
# 1982   {'spring': 78.51, 'fall': 77.52, 'winter': 76.65, 'summer': 77.71}
# 1983   {'spring': 79.67, 'fall': 77.83, 'winter': 76.83, 'summer': 77.88}
# 1984   {'spring': 78.19, 'fall': 77.35, 'winter': 75.76, 'summer': 77.25}
# 1985   {'spring': 78.16, 'fall': 77.14, 'winter': 76.36, 'summer': 77.4}
# 1986   {'spring': 78.33, 'fall': 77.39, 'winter': 76.19, 'summer': 77.99}
# 1987   {'spring': 78.56, 'fall': 78.42, 'winter': 76.55, 'summer': 78.05}
# 1988   {'spring': 79.06, 'fall': 77.6, 'winter': 76.46, 'summer': 77.67}
# 1989   {'spring': 77.86, 'fall': 77.23, 'winter': 76.17, 'summer': 77.62}
# 1990   {'spring': 78.8, 'fall': 77.64, 'winter': 75.92, 'summer': 77.73}
# 1991   {'spring': 78.5, 'fall': 76.9, 'winter': 76.19, 'summer': 77.56}
# 1992   {'spring': 78.74, 'fall': 76.47, 'winter': 75.3, 'summer': 77.42}
# 1993   {'spring': 77.49, 'fall': 77.19, 'winter': 75.17, 'summer': 77.41}
# 1994   {'spring': 77.49, 'fall': 76.68, 'winter': 76.31, 'summer': 76.78}
# 1995   {'spring': 77.97, 'fall': 77.17, 'winter': 75.69, 'summer': 77.4}
# 1996   {'spring': 77.86, 'fall': 76.82, 'winter': 75.23, 'summer': 77.39}
# 1997   {'spring': 78.18, 'fall': 77.86, 'winter': 76.45, 'summer': 77.77}
# 1998   {'spring': 79.73, 'fall': 77.83, 'winter': 77.74, 'summer': 78.11}
# 1999   {'spring': 77.71, 'fall': 77.11, 'winter': 76.02, 'summer': 76.83}
# 2000   {'spring': 78.27, 'fall': 77.58, 'winter': 76.65, 'summer': 77.27}
# 2001   {'spring': 78.15, 'fall': 77.35, 'winter': 76.78, 'summer': 77.46}
# 2002   {'spring': 78.91, 'fall': 77.71, 'winter': 76.95, 'summer': 77.66}
# 2003   {'spring': 78.77, 'fall': 77.51, 'winter': 76.71, 'summer': 77.97}
# 2004   {'spring': 79.06, 'fall': 77.42, 'winter': 76.88, 'summer': 77.76}
# 2005   {'spring': 78.71, 'fall': 77.66, 'winter': 77.35, 'summer': 78.08}
# 2006   {'spring': 78.52, 'fall': 77.5, 'winter': 76.85, 'summer': 77.62}
# 2007   {'spring': 78.29, 'fall': 77.18, 'winter': 76.14, 'summer': 77.58}
# 2008   {'spring': 77.47, 'fall': 77.5, 'winter': 76.33, 'summer': 77.13}
#
# Sydney
# 1948   {'spring': 58.02, 'fall': 59.7, 'winter': 69.99, 'summer': 47.87}
# 1949   {'spring': 58.69, 'fall': 59.56, 'winter': 71.74, 'summer': 47.58}
# 1950   {'spring': 59.25, 'fall': 59.2, 'winter': 69.18, 'summer': 48.92}
# 1951   {'spring': 58.69, 'fall': 61.2, 'winter': 68.45, 'summer': 48.44}
# 1952   {'spring': 58.64, 'fall': 60.31, 'winter': 72.96, 'summer': 48.5}
# 1953   {'spring': 60.84, 'fall': 61.79, 'winter': 70.51, 'summer': 47.79}
# 1954   {'spring': 60.97, 'fall': 60.64, 'winter': 68.36, 'summer': 49.51}
# 1955   {'spring': 59.76, 'fall': 62.85, 'winter': 69.65, 'summer': 48.83}
# 1956   {'spring': 58.29, 'fall': 58.52, 'winter': 69.92, 'summer': 46.49}
# 1957   {'spring': 61.09, 'fall': 63.56, 'winter': 73.57, 'summer': 50.22}
# 1958   {'spring': 62.59, 'fall': 60.96, 'winter': 68.64, 'summer': 49.83}
# 1959   {'spring': 60.62, 'fall': 60.43, 'winter': 69.08, 'summer': 50.19}
# 1960   {'spring': 59.57, 'fall': 60.24, 'winter': 70.45, 'summer': 48.58}
# 1961   {'spring': 60.77, 'fall': 61.4, 'winter': 69.17, 'summer': 48.79}
# 1962   {'spring': 59.29, 'fall': 60.9, 'winter': 66.92, 'summer': 49.75}
# 1963   {'spring': 60.89, 'fall': 60.3, 'winter': 69.88, 'summer': 48.5}
# 1964   {'spring': 61.25, 'fall': 60.62, 'winter': 70.76, 'summer': 49.6}
# 1965   {'spring': 61.33, 'fall': 63.96, 'winter': 69.92, 'summer': 49.75}
# 1966   {'spring': 60.88, 'fall': 59.7, 'winter': 70.66, 'summer': 48.65}
# 1967   {'spring': 60.87, 'fall': 62.34, 'winter': 70.39, 'summer': 50.17}
# 1968   {'spring': 62.01, 'fall': 62.89, 'winter': 70.41, 'summer': 48.16}
# 1969   {'spring': 60.88, 'fall': 58.46, 'winter': 71.83, 'summer': 50.79}
# 1970   {'spring': 59.82, 'fall': 59.12, 'winter': 70.96, 'summer': 48.68}
# 1971   {'spring': 59.92, 'fall': 60.0, 'winter': 69.1, 'summer': 48.22}
# 1972   {'spring': 60.4, 'fall': 61.16, 'winter': 69.29, 'summer': 49.71}
# 1973   {'spring': 62.72, 'fall': 61.25, 'winter': 70.89, 'summer': 50.63}
# 1974   {'spring': 61.05, 'fall': 58.22, 'winter': 70.08, 'summer': 48.47}
# 1975   {'spring': 60.25, 'fall': 61.0, 'winter': 71.28, 'summer': 50.11}
# 1976   {'spring': 60.57, 'fall': 58.36, 'winter': 70.08, 'summer': 49.22}
# 1977   {'spring': 60.85, 'fall': 62.25, 'winter': 71.61, 'summer': 48.85}
# 1978   {'spring': 61.21, 'fall': 59.53, 'winter': 69.64, 'summer': 47.87}
# 1979   {'spring': 59.95, 'fall': 61.4, 'winter': 74.06, 'summer': 49.79}
# 1980   {'spring': 62.31, 'fall': 63.82, 'winter': 70.8, 'summer': 49.85}
# 1981   {'spring': 61.56, 'fall': 61.47, 'winter': 72.31, 'summer': 47.74}
# 1982   {'spring': 61.12, 'fall': 61.83, 'winter': 72.4, 'summer': 49.6}
# 1983   {'spring': 61.28, 'fall': 60.7, 'winter': 71.06, 'summer': 48.36}
# 1984   {'spring': 59.36, 'fall': 59.27, 'winter': 67.74, 'summer': 49.0}
# 1985   {'spring': 59.83, 'fall': 58.34, 'winter': 70.49, 'summer': 48.44}
# 1986   {'spring': 62.06, 'fall': 58.88, 'winter': 68.98, 'summer': 48.1}
# 1987   {'spring': 59.47, 'fall': 60.18, 'winter': 71.24, 'summer': 49.61}
# 1988   {'spring': 60.48, 'fall': 63.08, 'winter': 70.18, 'summer': 50.91}
# 1989   {'spring': 62.23, 'fall': 59.81, 'winter': 67.77, 'summer': 47.64}
# 1990   {'spring': 61.26, 'fall': 60.78, 'winter': 71.69, 'summer': 47.91}
# 1991   {'spring': 61.41, 'fall': 62.0, 'winter': 71.22, 'summer': 50.13}
# 1992   {'spring': 60.13, 'fall': 56.92, 'winter': 66.97, 'summer': 48.53}
# 1993   {'spring': 60.43, 'fall': 58.49, 'winter': 70.46, 'summer': 50.06}
# 1994   {'spring': 58.84, 'fall': 59.01, 'winter': 71.63, 'summer': 48.61}
# 1995   {'spring': 59.25, 'fall': 60.51, 'winter': 67.54, 'summer': 49.6}
# 1996   {'spring': 59.8, 'fall': 59.42, 'winter': 67.82, 'summer': 48.91}
# 1997   {'spring': 61.41, 'fall': 61.84, 'winter': 71.14, 'summer': 49.22}
# 1998   {'spring': 61.8, 'fall': 59.06, 'winter': 71.51, 'summer': 49.61}
# 1999   {'spring': 60.56, 'fall': 59.74, 'winter': 68.8, 'summer': 50.16}
# 2000   {'spring': 60.44, 'fall': 61.36, 'winter': 69.79, 'summer': 48.44}
# 2001   {'spring': 60.18, 'fall': 60.43, 'winter': 72.98, 'summer': 49.97}
# 2002   {'spring': 61.32, 'fall': 64.2, 'winter': 69.82, 'summer': 50.07}
# 2003   {'spring': 59.74, 'fall': 59.23, 'winter': 72.05, 'summer': 49.66}
# 2004   {'spring': 60.9, 'fall': 60.83, 'winter': 71.96, 'summer': 48.93}
# 2005   {'spring': 61.14, 'fall': 60.73, 'winter': 72.26, 'summer': 49.74}
# 2006   {'spring': 59.22, 'fall': 62.62, 'winter': 71.53, 'summer': 48.98}
# 2007   {'spring': 61.36, 'fall': 61.15, 'winter': 68.87, 'summer': 48.54}
# 2008   {'spring': 58.71, 'fall': 61.47, 'winter': 67.97, 'summer': 48.64}
#
# Vancouver
# 1948   {'spring': 33.77, 'fall': 38.45, 'winter': 21.78, 'summer': 55.03}
# 1949   {'spring': 38.03, 'fall': 43.27, 'winter': 18.39, 'summer': 52.7}
# 1950   {'spring': 33.11, 'fall': 39.66, 'winter': 20.27, 'summer': 56.35}
# 1951   {'spring': 34.87, 'fall': 40.86, 'winter': 21.43, 'summer': 56.47}
# 1952   {'spring': 35.86, 'fall': 43.51, 'winter': 24.87, 'summer': 55.12}
# 1953   {'spring': 35.46, 'fall': 43.18, 'winter': 28.63, 'summer': 53.21}
# 1954   {'spring': 32.26, 'fall': 41.6, 'winter': 25.55, 'summer': 50.22}
# 1955   {'spring': 29.71, 'fall': 37.33, 'winter': 22.55, 'summer': 52.86}
# 1956   {'spring': 37.05, 'fall': 39.16, 'winter': 23.16, 'summer': 54.64}
# 1957   {'spring': 38.51, 'fall': 42.22, 'winter': 21.21, 'summer': 50.9}
# 1958   {'spring': 38.98, 'fall': 38.74, 'winter': 31.05, 'summer': 59.0}
# 1959   {'spring': 35.19, 'fall': 38.01, 'winter': 24.96, 'summer': 52.46}
# 1960   {'spring': 34.46, 'fall': 39.97, 'winter': 23.84, 'summer': 53.23}
# 1961   {'spring': 36.2, 'fall': 36.95, 'winter': 27.21, 'summer': 58.66}
# 1962   {'spring': 34.31, 'fall': 41.99, 'winter': 25.66, 'summer': 51.63}
# 1963   {'spring': 36.15, 'fall': 42.42, 'winter': 25.73, 'summer': 52.9}
# 1964   {'spring': 33.41, 'fall': 38.24, 'winter': 23.76, 'summer': 51.0}
# 1965   {'spring': 33.9, 'fall': 41.27, 'winter': 25.15, 'summer': 55.75}
# 1966   {'spring': 35.29, 'fall': 40.97, 'winter': 26.79, 'summer': 52.09}
# 1967   {'spring': 31.98, 'fall': 40.54, 'winter': 25.23, 'summer': 54.58}
# 1968   {'spring': 33.18, 'fall': 37.61, 'winter': 20.58, 'summer': 52.6}
# 1969   {'spring': 36.34, 'fall': 40.1, 'winter': 21.69, 'summer': 52.39}
# 1970   {'spring': 33.24, 'fall': 37.33, 'winter': 25.04, 'summer': 54.5}
# 1971   {'spring': 34.07, 'fall': 37.48, 'winter': 23.62, 'summer': 53.1}
# 1972   {'spring': 35.2, 'fall': 36.64, 'winter': 20.55, 'summer': 52.13}
# 1973   {'spring': 34.18, 'fall': 35.14, 'winter': 23.44, 'summer': 48.91}
# 1974   {'spring': 32.33, 'fall': 38.64, 'winter': 23.19, 'summer': 50.59}
# 1975   {'spring': 31.09, 'fall': 36.81, 'winter': 21.15, 'summer': 50.61}
# 1976   {'spring': 32.17, 'fall': 40.64, 'winter': 26.38, 'summer': 48.68}
# 1977   {'spring': 34.22, 'fall': 35.97, 'winter': 24.56, 'summer': 52.64}
# 1978   {'spring': 34.7, 'fall': 35.28, 'winter': 22.85, 'summer': 53.89}
# 1979   {'spring': 35.41, 'fall': 39.7, 'winter': 21.67, 'summer': 53.62}
# 1980   {'spring': 35.63, 'fall': 38.66, 'winter': 24.01, 'summer': 49.72}
# 1981   {'spring': 35.25, 'fall': 38.08, 'winter': 25.9, 'summer': 51.46}
# 1982   {'spring': 33.01, 'fall': 37.21, 'winter': 22.74, 'summer': 53.07}
# 1983   {'spring': 37.61, 'fall': 36.71, 'winter': 23.11, 'summer': 50.28}
# 1984   {'spring': 34.07, 'fall': 35.48, 'winter': 23.36, 'summer': 50.64}
# 1985   {'spring': 34.54, 'fall': 30.81, 'winter': 22.44, 'summer': 53.2}
# 1986   {'spring': 35.3, 'fall': 37.66, 'winter': 26.09, 'summer': 52.25}
# 1987   {'spring': 36.71, 'fall': 40.88, 'winter': 25.89, 'summer': 52.23}
# 1988   {'spring': 36.12, 'fall': 39.84, 'winter': 25.03, 'summer': 50.72}
# 1989   {'spring': 35.22, 'fall': 39.57, 'winter': 22.53, 'summer': 51.43}
# 1990   {'spring': 35.94, 'fall': 38.53, 'winter': 22.53, 'summer': 53.67}
# 1991   {'spring': 34.37, 'fall': 38.83, 'winter': 26.82, 'summer': 51.22}
# 1992   {'spring': 38.72, 'fall': 37.09, 'winter': 26.79, 'summer': 54.22}
# 1993   {'spring': 37.07, 'fall': 39.12, 'winter': 21.93, 'summer': 49.86}
# 1994   {'spring': 37.77, 'fall': 38.17, 'winter': 25.58, 'summer': 52.89}
# 1995   {'spring': 36.79, 'fall': 41.29, 'winter': 26.42, 'summer': 52.07}
# 1996   {'spring': 34.28, 'fall': 36.36, 'winter': 21.85, 'summer': 53.51}
# 1997   {'spring': 36.0, 'fall': 40.67, 'winter': 26.2, 'summer': 53.75}
# 1998   {'spring': 37.6, 'fall': 41.82, 'winter': 26.13, 'summer': 56.01}
# 1999   {'spring': 32.29, 'fall': 39.46, 'winter': 27.72, 'summer': 50.79}
# 2000   {'spring': 35.97, 'fall': 37.91, 'winter': 24.88, 'summer': 51.81}
# 2001   {'spring': 35.74, 'fall': 39.46, 'winter': 25.41, 'summer': 51.31}
# 2002   {'spring': 33.0, 'fall': 39.54, 'winter': 26.85, 'summer': 53.86}
# 2003   {'spring': 34.98, 'fall': 39.82, 'winter': 28.06, 'summer': 54.23}
# 2004   {'spring': 39.56, 'fall': 40.11, 'winter': 27.83, 'summer': 57.64}
# 2005   {'spring': 39.66, 'fall': 39.35, 'winter': 25.68, 'summer': 53.44}
# 2006   {'spring': 36.58, 'fall': 40.47, 'winter': 27.2, 'summer': 55.31}
# 2007   {'spring': 36.12, 'fall': 38.88, 'winter': 26.24, 'summer': 53.33}
# 2008   {'spring': 34.43, 'fall': 41.73, 'winter': 23.74, 'summer': 52.5}

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.io import loadmat
import matplotlib as mpl
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

def data_format(series):
	time = series['time']
	temp = series['temperature']

	time_temp = zip(time, temp)
	win = ['12', '01', '02']
	spr = ['03', '04', '05']
	sumer = ['06', '07', '08']
	fal   = ['09', '10', '11']

	year = {}
	
	for k, v in enumerate(range(1948, 2009)):
		q = []
		winter = []
		spring = []
		summer = []
		fall = []
		season = {}
		for i, j in time_temp:
			if i[0:4] == str(v):
				if i[5:7] in win:
					j[0] = k2f(j[0])
					winter.append(j[0])
				elif i[5:7] in spr:
					j[0] = k2f(j[0])
					spring.append(j[0])
				elif i[5:7] in sumer:
					j[0] = k2f(j[0])
					summer.append(j[0])
				elif i[5:7] in fal:
					j[0] = k2f(j[0])
					fall.append(j[0])

		season['winter'] = round(np.average(winter), 2)
		season['spring'] = round(np.average(spring), 2)
		season['summer'] = round(np.average(summer), 2)
		season['fall']   = round(np.average(fall), 2)
		
		year[v] = season

	return year

def k2f(t):
    return (t*9/5.0) - 459.67

def set_Spines(x):
	x.spines['top'].set_visible(False)
	x.spines['bottom'].set_linewidth(.8)
	x.xaxis.set_ticks_position('bottom')

	x.spines['right'].set_visible(False)
	x.spines['left'].set_linewidth(0.8)
	x.yaxis.set_ticks_position('left')

def main():
	data = loadmat('Johannesburg.mat')
	series = Series(data)
	Johannesburg = data_format(series)
	sorted(Johannesburg.keys())
	fig = plt.figure(figsize=(18,12))
	gs = mpl.gridspec.GridSpec(1,1)
	ax = fig.add_subplot(gs[0])
	plt.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)
	set_Spines(ax)

	x = Johannesburg.values()
	Joh_winter = []
	Joh_spring = []
	Joh_summer = []
	Joh_fall = []
	for i in x:
		Joh_winter.append(i['winter'])
		Joh_spring.append(i['spring'])
		Joh_summer.append(i['summer'])
		Joh_fall.append(i['fall'])

	line1 = ax.plot(Johannesburg.keys(), Joh_winter, marker='.', color='navy', label='Winter')
	line2 = ax.plot(Johannesburg.keys(), Joh_spring, marker='.', color='red', label='Spring')
	line3 = ax.plot(Johannesburg.keys(), Joh_summer, marker='.', color='blue', label='Summer')
	line4 = ax.plot(Johannesburg.keys(), Joh_fall, marker='.', color='black', label='Fall')
    
	ax.set_xticks(Johannesburg.keys())
	ax.set_xticklabels(Johannesburg.keys(), rotation=45, fontsize=9)
	ax.set_title('Johannesburg (Temperature 1948 - 1960)')
	ax.set_xlabel('Years')
	ax.set_ylabel('Temperature (Farh)')

	ax.set_xlim((1948,2008))
	ax.legend(loc='lower right')

	fig.savefig('figure_1.png')

if __name__ == '__main__':
	main()

# %% [markdown]
# The above graph shows the temperature in Johannesburg from 1948 to 2008 for the four different seasons.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.io import loadmat
import matplotlib as mpl
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

def data_format(series):
	time = series['time']
	temp = series['temperature']

	time_temp = zip(time, temp)
	win = ['12', '01', '02']
	spr = ['03', '04', '05']
	sumer = ['06', '07', '08']
	fal   = ['09', '10', '11']

	year = {}
	
	for k, v in enumerate(range(1948, 2009)):
		q = []
		winter = []
		spring = []
		summer = []
		fall = []
		season = {}
		for i, j in time_temp:
			if i[0:4] == str(v):
				if i[5:7] in win:
					j[0] = k2f(j[0])
					winter.append(j[0])
				elif i[5:7] in spr:
					j[0] = k2f(j[0])
					spring.append(j[0])
				elif i[5:7] in sumer:
					j[0] = k2f(j[0])
					summer.append(j[0])
				elif i[5:7] in fal:
					j[0] = k2f(j[0])
					fall.append(j[0])

		season['winter'] = round(np.average(winter), 2)
		season['spring'] = round(np.average(spring), 2)
		season['summer'] = round(np.average(summer), 2)
		season['fall']   = round(np.average(fall), 2)
		
		year[v] = season

	return year

def k2f(t):
    return (t*9/5.0) - 459.67

def set_Spines(x):
	x.spines['top'].set_visible(False)
	x.spines['bottom'].set_linewidth(.8)
	x.xaxis.set_ticks_position('bottom')

	x.spines['right'].set_visible(False)
	x.spines['left'].set_linewidth(0.8)
	x.yaxis.set_ticks_position('left')

def main():
	data = loadmat('Johannesburg.mat')
	series = Series(data)
	Johannesburg = data_format(series)
	sorted(Johannesburg.keys())

	data = loadmat('Paris.mat')
	series = Series(data)
	Paris = data_format(series)
	sorted(Paris.keys())

	data = loadmat('SaoPaulo.mat')
	series = Series(data)
	SaoPaulo = data_format(series)
	sorted(SaoPaulo.keys())

	data = loadmat('Singapore.mat')
	series = Series(data)
	Singapore = data_format(series)
	sorted(Singapore.keys())

	data = loadmat('Sydney.mat')
	series = Series(data)
	Sydney = data_format(series)
	sorted(Sydney.keys())

	data = loadmat('Vancouver.mat')
	series = Series(data)
	Vancouver = data_format(series)
	sorted(Vancouver.keys())
    
	fig = plt.figure(figsize=(18,12))
	gs = mpl.gridspec.GridSpec(1,1)
	ax = fig.add_subplot(gs[0])
	plt.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)
	set_Spines(ax)

	x = Johannesburg.values()
	Joh_winter = []
	for i in x:
		Joh_winter.append(i['winter'])

	x = Paris.values()
	Paris_winter = []
	for i in x:
		Paris_winter.append(i['winter']) 
    
	x = SaoPaulo.values()
	SaoPaulo_winter = []
	for i in x:
		SaoPaulo_winter.append(i['winter'])
        
	x = Singapore.values()
	Singapore_winter = []
	for i in x:
		Singapore_winter.append(i['winter'])
        
	x = Sydney.values()
	Sydney_winter = []
	for i in x:
		Sydney_winter.append(i['winter'])
            
	x = Vancouver.values()
	Vancouver_winter = []
	for i in x:
		Vancouver_winter.append(i['winter'])
        
	line1 = ax.plot( Johannesburg.keys(), Joh_winter, color='navy', label='Johannesburg Winter')
	line2 = ax.plot( Paris.keys(), Paris_winter, color='red', label='Paris Winter')
	line3 = ax.plot( SaoPaulo.keys(), SaoPaulo_winter, color='blue', label='SaoPaulo Winter') 
	line4 = ax.plot( Singapore.keys(), Singapore_winter, color='black', label='Singapore Winter')
	line5 = ax.plot( Sydney.keys(), Sydney_winter, color='green', label='Sydney Winter')
	line6 = ax.plot( Vancouver.keys(), Vancouver_winter, color='orange', label='Vancouver Winter')
    
	ax.set_xticks(Johannesburg.keys())
	ax.set_xticklabels(Johannesburg.keys(), rotation=45, fontsize=9)
	ax.set_title('Winter around the World (Temperature 1948 - 1960)')
	ax.set_xlabel('Years')
	ax.set_ylabel('Temperature (Farh)')
    
	ax.set_xlim((1948,2008))
	ax.set_ylim((0,100))
	ax.legend(loc='lower right')

	fig.savefig('fig.png')

if __name__ == '__main__':
	main()
